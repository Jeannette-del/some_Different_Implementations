# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# instructions to follow:

# check your email for the dataset (csv file)

# upload it to your drive


# check online how to mount your drive in colab

# mount your drive 

# check your current directory using the command 'pwd'

# use the command 'cd' to specify the location of your uploaded dataset

# confirm that by using the 'ls' command

# Read the data using pandas

# Solve the excercises below

# Deadline is midnight today

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pwd -P
# Out:
# '/content'

# %%
cd Mydrive
# Out:
# [Errno 2] No such file or directory: 'Mydrive'
# /content

# %%
! ls '/content/gdrive/MyDrive'
# Out:
# 'Colab Notebooks'   company_sales_data.csv

# %%
path = '/content/gdrive/MyDrive/company_sales_data.csv'
df= pd.read_csv(path)

# %%
df.head()
# Out:
#    month_number  facecream  facewash  ...  moisturizer  total_units  total_profit
# 0             1       2500      1500  ...         1500        21100        211000
# 1             2       2630      1200  ...         1200        18330        183300
# 2             3       2140      1340  ...         1340        22470        224700
# 3             4       3400      1130  ...         1130        22270        222700
# 4             5       3600      1740  ...         1740        20960        209600
#
# [5 rows x 9 columns]

# %% [markdown]
# #*Exercise 1:*
# Read Total profit of all months and show it using a line plot
#
# Total profit data provided for each month. Generated line plot must include the following properties: –
#
# * X label name = Month Number
# * Y label name = Total profit
# * The line plot graph should look like this.
#
# ![](https://pynative.com/wp-content/uploads/2019/01/matplotlib_and_pandas_exercise_1_plot_company_profit.png)

# %%
plt.figure(figsize=(10,6))
X = df['month_number']
Y = df['total_profit']
plt.plot(X,Y,linewidth=5)
plt.xlabel('Month Number',size=20)
plt.ylabel('Total profit',size=20)
plt.title('Company profit per Month',size=20)
plt.show()

# %%
plt.figure(figsize=(10,6))
X = df['month_number']
Y = df['total_profit']
plt.plot(X,Y, color='red',ls='dashed',label='Profit data of last year',marker='o',ms=10,mfc='k',linewidth=6)
plt.xlabel('Month Number',size=20)
plt.ylabel('Sold Units number',size=20)
plt.title('Company Sales data of last year',size=20)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # *Exercise Question 2:*
# Get Total profit of all months and show line plot with the following Style properties
# Generated line plot must include following Style properties: –
#
# * Line Style dotted and Line-color should be red
# * Show legend at the lower right location.
# * X label name = Month Number
# * Y label name = Sold units number
# * Add a circle marker.
# * Line marker color as read
# * Line width should be 3
# The line plot graph should look like this.
#
# ![](https://pynative.com/wp-content/uploads/2019/01/matplotlib_and_pandas_exercise_2_plot_style_properties.png)

# %% [markdown]
# # *Exercise Question 3: Read all product sales data and show it  using a multiline pl*
#
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
#
# The graph should look like this.
#
# ![](https://pynative.com/wp-content/uploads/2019/01/matplotlib_and_pandas_exercise_3_multiline_plots.png)

# %%
plt.figure(figsize=(10,6))
x = df.columns[1:7]
for i in range(6):
  plt.plot(df['month_number'], df[df.columns[i]], label=df.columns[1:7][i],linewidth=6,marker='o',ms=10)
plt.legend(loc='upper left')
plt.xlabel('Month Number',size=20)
plt.ylabel('Sold Units number',size=20)
plt.title('Sales data',size=20)

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #*Exercise Question 4: Read toothpaste sales data of each month and show it using a scatter plot*
#
# Also, add a grid in the plot. gridline style should “–“.
#
# The scatter plot should look like this.
#
# ![](https://pynative.com/wp-content/uploads/2019/01/matplotlib_and_pandas_exercise_4_show_scatter_plot.png)

# %%
plt.figure(figsize=(10,6))

plt.scatter(df['month_number'],df['toothpaste'],label='Tooth paste Sales data', s=100)
plt.xlabel('Month Number',size=20)
plt.ylabel('Number of Units SOld',size=20)
plt.title('Tooth paste Sales data',size=20)
plt.legend(loc='upper left')
plt.grid(ls ='--',linewidth=2)
plt.show()

# %% [markdown]
# #*Exercise Question 5: Read face cream and facewash product sales data and show it using the bar chart*
#
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this.
#
# ![](https://pynative.com/wp-content/uploads/2019/01/matplotlib_panadas_exercise_5_show_bar_chart.png)

# %%
plt.figure(figsize=(10,6))
u = df['facecream']
v = df['facewash']
barwidth = 0.4
x = np.arange(len(df))

plt.bar(x-barwidth/2, u, barwidth, label='Face Cream Sales Data')
plt.bar(x+barwidth/2, v, barwidth,label='Facewash Sales Data')
plt.xlabel('Month Number',size=20)
plt.ylabel('Sales units in Number',size=20)
plt.title('Facewash and Facecream sales data',size=20)
plt.legend(loc='upper left')
plt.grid(ls='--')
plt.show()

# %% [markdown]
# plt.bar(x-barwidth/2, u, barwidth)#*Exercise Question 6: Read the total profit of each month and show it using the histogram to see most common profit ranges*
#
# The histogram should look like this.
#
# ![](https://pynative.com/wp-content/uploads/2019/01/matplotlib_panadas_exercise_7_histogram.png)

# %%
plt.figure(figsize=(10,6))
y = df['total_profit']
ranges = [150000, 175000, 200000, 225000,250000,300000, 350000]
plt.hist(y, bins=ranges, label='Profit data')
plt.xlabel('Profit range in dollar',size=20)
plt.ylabel('Actual profit in dollar',size=20)
plt.title('Profit data',size=20)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# #*Exercise Question 7: Read Bathing soap facewash of all months and display it using the Subplot*
# The Subplot should look like this.
#
# ![](https://pynative.com/wp-content/uploads/2019/01/matplotlib_pandas_exercise_9_show_sub_plot.png)

# %%
plt.figure(figsize=(10,6))
n=df['bathingsoap']
m=df['facewash']
plt.subplot(2,1,1)
plt.plot(df['month_number'],n,color='k',linewidth=6,marker='o',ms=15)
plt.title('Sales data of bathing Soap',size=20)
plt.subplot(2,1,2)
plt.plot(df['month_number'],m,color='r',linewidth=6,marker='o',ms=15)
plt.xlabel('MOnth NUmber',size=20)
plt.ylabel('Sales units in number',size=20)
plt.title('Sales data of facewash',size=20)
plt.show()

# %% [markdown]
# #*Exercise Question 8: Read all product sales data and show it using the stack plot*
#
# The Stack plot should look like this.
#
# ![](https://pynative.com/wp-content/uploads/2019/01/matplotbib_pandas_exercise10_show_stack_plot.png)

# %%
plt.figure(figsize=(10,6))
y1 = df[df.columns[1:7][0]]
y2 =df[ df.columns[1:7][1]]
y3 =df[ df.columns[1:7][2]]
y4 = df[df.columns[1:7][3]]
y5 = df[df.columns[1:7][4]]
y6 = df[df.columns[1:7][5]]

colors = ['purple','cyan','red','black','green','olive']
labels = df.columns[1:7]

# y = df[y_cols]
y_stack = np.vstack((y1, y2, y3, y4, y5, y6))
plt.stackplot(df['month_number'], y_stack, colors=colors, labels=labels)
plt.xlabel('MOnth NUmber',size=20)
plt.ylabel('Sales Units in Number',size=20)
plt.legend(loc='upper left')
plt.title('All products sales data using stack plot',size=20)
plt.show()
# z = np.vstack()
